# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.hermite import hermval
from scipy.misc import factorial
# Out:
# /home/raroog/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Reproduction: Shirvany, et. al., "Numerical solution of the nonlinear Schrodinger equation by feedforward neural networks."

# %% [markdown]
# The authors propose the solution of a form of a almost-shallow network where we have a single hidden layer with $n_h$ units with sigmoid activation function. Output of the hidden layer is passed to an output layer with $n_o=2$ linear units which in the end are reduced by multipication.

# %%
class Solution(tf.keras.models.Model):
  def __init__(self, n_i, n_h, n_o=1, activation='sigmoid'):
    super(Solution, self).__init__()
    
    # Dimension of all the layers
    self.n_i = n_i
    self.n_h = n_h
    self.n_o = n_o
    
    # Shallow network
    # Hidden layer
    self.hidden_layer = tf.keras.layers.Dense(units=n_h, activation=activation)
    # Output layer
    self.output_layer = tf.keras.layers.Dense(units=n_o, activation='linear')
    
  def call(self, X):
    # Conversion to a tensor
    X = tf.convert_to_tensor(X)
    # Simple Shallow Network Response
    response = self.hidden_layer(X)
    response = self.output_layer(X)
    
    # Reduction by product of the output (For the work n_o=2)
    response = tf.math.reduce_prod(response, axis=1)
    
    return response
  
  def train(self, X, conditions, eigen_value, loss_function, loss_boundary,
            epochs, verbose=True, message_frequency=1, learning_rate=0.1,
            optimizer_name='Adam'):
    
    # Checking for the right parameters
    if not isinstance(epochs, int) or epochs < 1:
      raise Exception('epochs parameter should be a positive integer.')
    if not isinstance(message_frequency, int) or message_frequency < 1:
      raise Exception(
                'message_frequency parameter should be a positive integer.')
      
    # Choosing the optimizers
    optimizer = 0
    if optimizer_name == 'Adam':
      optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer_name == 'SGD':
      optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    elif optimizer_name == 'Adagrad':
      optimizer = tf.keras.optimizers.Adagrad(learning_rate=learning_rate)
    train_loss = tf.keras.metrics.Mean('train')
    
    # Single train step function for the unsupervised equation part
    @tf.function
    def train_step(X, eigen_value):
      with tf.GradientTape() as tape:
        loss = loss_function(self, X, eigen_value)
      gradients = tape.gradient(loss, self.trainable_variables)
      optimizer.apply_gradients(
                  zip(gradients, self.trainable_variables))
      
    # Single train step function for the supervised boundary part
    @tf.function
    def train_boundary(conditions):
      with tf.GradientTape() as tape:
        loss = loss_boundary(self, conditions)
      gradients = tape.gradient(loss, self.trainable_variables)
      optimizer.apply_gradients(
                  zip(gradients, self.trainable_variables))
    
    # Training for a given number of epochs
    for epoch in range(epochs):
      for x in X:
        x_tensor = tf.reshape(x, shape=(1, X.shape[1]))
        train_step(x_tensor, eigen_value)
      train_boundary(conditions)
      train_loss(loss_function(self, X, eigen_value) + loss_boundary(self, conditions))
      if verbose and(epoch+1) % message_frequency == 0:
        print(f'Epoch: {epoch+1} Loss: {train_loss.result().numpy()}')

# %% [markdown]
# Accroding to the paper:
#
# >The ANN is trained via the gradient-descent back-propagation method with momentum
# term for minimizing the non-negative energy function that is formulated from Schrodinger equation Eq. (6)
# and the available boundary conditions.
#
# and
#
# >In the train
# state of the network the adjustable parameters of the networks (weights and biases) are tuned by a proper
# learning algorithm to minimize the energy function of the network. We train the network via the fast converge
# gradient-descend back-propagation method with momentum term [7,23,24] for the non-negative energy func-
# tion.
#
# We concluded that it can realised by using the Adam optimizer with online learning.

# %% [markdown]
# The loss is defined by sum of unsupervised minimalization of the equation and by supervised optimization for MSE for the boundary conditions:
# $$Loss(N)=\sum_i \left(\Delta\Psi(N(x_i))+E\Psi(N(x_i))\right)^2 + \sum_k (\Psi(N(x_k))-C_k)^2$$

# %% [markdown]
# ## Potential Well

# %% [markdown]
# We consider the Shroedinger equation in one dimension:
# $$-\frac{d^2}{dx^2}\Psi(x)+V(x)\Psi(x)=E\Psi(x)$$
# For the Potential Well problem with
# $$V(x)=\begin{cases}
#       0, & x\in[0,L] \\
#       \infty, & x\notin(0,L)
#    \end{cases}$$
# The equivalent formulation is $V(x)=0$ on the whole domain with the boundary conditions $\Psi(0)=0$ and $\Psi(L)=0$ with the domain of the equation $x\in[0,L]$.
#
#
# Where we set $\frac{\hbar^2}{2m}=1$.

# %% [markdown]
# We set the lenght of the well equal to $4$.

# %%
L = 4.

# %% [markdown]
# We take 200 equally separated points from the interval $[0, L]$ for the training set and more for the test set.

# %%
X_train = np.arange(0, L, L/200) + 1e-8
X_train = X_train.reshape(-1,1)
X_test = np.arange(0, L, 0.001) + 1e-8
X_test = X_test.reshape(-1,1)

# %%
# Defining the boundary conditions
bcs = [{'variable':0, 'value':0, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)}]

# %% [markdown]
# The term of the loss function representing the equation satisfaction $\sum_i \left(\Delta\Psi(N(x_i))+E\Psi(N(x_i))\right)^2$

# %%
def loss_well(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  # Taking the frist (grads) and the second (laplace) derivatives w. r. t. inputs
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  
  # Constant tensor of the eigen value
  eigen_value_tensor = tf.constant(eigen_value, shape=(X.shape[0], 1), dtype='float64')
  
  
  loss = tf.square(laplace + eigen_value_tensor * response)
  return loss

# %% [markdown]
# The term of the loss function representing the boundary conditions $\sum_k (\Psi(N(x_k))-C_k)^2$

# %%
def loss_boundary(network, conditions):
  loss = 0
  for condition in conditions:
    temp_X = tf.convert_to_tensor(np.array([condition['value']]).reshape((1,1)))
    loss += tf.square(network(temp_X) - condition['function'](temp_X))
  return loss

# %% [markdown]
# The authors have found $n_h=105$ to be optimal size of the network.
#
# Let's check if such a solution finds the eigen function corresponidng to the first $5$ eigen_values calculated as $E(n)=\left(\frac{n\pi}{L} \right)^2,\, n=1,2,3,\dots$ .

# %%
def eigen_value_well(n):
  return (n * np.pi / L)**2

# %%
for n in range(1, 7):
  sol = Solution(n_i=1, n_h=105, n_o=2)
  sol.train(X=X_train, conditions=bcs, eigen_value=eigen_value_well(n), loss_function=loss_well,
            loss_boundary=loss_boundary, epochs=1000, verbose=False, message_frequency=10,
            learning_rate=0.1, optimizer_name='Adam')
  pred_train = sol.call(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
  pred_test = sol(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
  plt.scatter(X_train, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_test, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_test, np.sin(n*np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
# Out:
# W0504 22:13:40.175750 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_6/dense_12/kernel:0', 'solution_6/dense_12/bias:0'] when minimizing the loss.
# W0504 22:13:41.314270 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_6/dense_12/kernel:0', 'solution_6/dense_12/bias:0'] when minimizing the loss.
# W0504 22:13:42.261291 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_6/dense_12/kernel:0', 'solution_6/dense_12/bias:0'] when minimizing the loss.
# W0504 22:13:57.850453 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_7/dense_14/kernel:0', 'solution_7/dense_14/bias:0'] when minimizing the loss.
# W0504 22:13:58.960058 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_7/dense_14/kernel:0', 'solution_7/dense_14/bias:0'] when minimizing the loss.
# W0504 22:13:59.887201 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_7/dense_14/kernel:0', 'solution_7/dense_14/bias:0'] when minimizing the loss.
# W0504 22:14:15.492998 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_8/dense_16/kernel:0', 'solution_8/dense_16/bias:0'] when minimizing the loss.
# W0504 22:14:16.610537 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_8/dense_16/kernel:0', 'solution_8/dense_16/bias:0'] when minimizing the loss.
# W0504 22:14:17.530606 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_8/dense_16/kernel:0', 'solution_8/dense_16/bias:0'] when minimizing the loss.
# W0504 22:14:34.155439 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_9/dense_18/kernel:0', 'solution_9/dense_18/bias:0'] when minimizing the loss.
# W0504 22:14:35.262726 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_9/dense_18/kernel:0', 'solution_9/dense_18/bias:0'] when minimizing the loss.
# W0504 22:14:36.244278 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_9/dense_18/kernel:0', 'solution_9/dense_18/bias:0'] when minimizing the loss.
# W0504 22:14:52.139468 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_10/dense_20/kernel:0', 'solution_10/dense_20/bias:0'] when minimizing the loss.
# W0504 22:14:53.279744 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_10/dense_20/kernel:0', 'solution_10/dense_20/bias:0'] when minimizing the loss.
# W0504 22:14:54.215993 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_10/dense_20/kernel:0', 'solution_10/dense_20/bias:0'] when minimizing the loss.
# W0504 22:15:11.441797 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_11/dense_22/kernel:0', 'solution_11/dense_22/bias:0'] when minimizing the loss.
# W0504 22:15:12.667819 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_11/dense_22/kernel:0', 'solution_11/dense_22/bias:0'] when minimizing the loss.
# W0504 22:15:13.633775 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_11/dense_22/kernel:0', 'solution_11/dense_22/bias:0'] when minimizing the loss.

# %% [markdown]
# Supprisingly, the network converges to the trivial vanishing solution of the equation instead of the real physical solution despite what the authors have reported.

# %% [markdown]
# ### Let's try to fix it by adding an additional point
#
# By analytic considerations, we know that for $n=1$ the maximum of the eigenfunction is for $x=L/2$ and is equal to $\Psi(L/2)=2^{-0.5}$, so let's add it as an additional initial condition.

# %%
bcs2 = [{'variable':0, 'value':0, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)},
      {'variable':0, 'value':L*0.5, 'type':'dirichlet',
        'function':lambda X: tf.constant(np.power(2,-0.5), dtype='float64', shape=X.shape)}]

# %%
sol2 = Solution(n_i=1, n_h=105, n_o=2)

# %%
sol2.train(X=X_train, conditions=bcs2, eigen_value=eigen_value_well(1), loss_function=loss_well,
           loss_boundary=loss_boundary, epochs=10000, message_frequency=10,learning_rate=0.01,
           optimizer_name='SGD')
# Out:
# W0504 22:22:34.661195 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_16/dense_32/kernel:0', 'solution_16/dense_32/bias:0'] when minimizing the loss.
# W0504 22:22:35.762663 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_16/dense_32/kernel:0', 'solution_16/dense_32/bias:0'] when minimizing the loss.
# W0504 22:22:36.588113 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_16/dense_32/kernel:0', 'solution_16/dense_32/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 1.165217399597168
# Epoch: 20 Loss: 1.7970720529556274
# Epoch: 30 Loss: 1.3113594055175781
# Epoch: 40 Loss: 1.1455966234207153
# Epoch: 50 Loss: 1.065348505973816
# Epoch: 60 Loss: 1.0029746294021606
# Epoch: 70 Loss: 0.9453931450843811
# Epoch: 80 Loss: 0.8913838267326355
# Epoch: 90 Loss: 0.8413531184196472
# Epoch: 100 Loss: 0.7955051064491272
# Epoch: 110 Loss: 0.7537427544593811
# Epoch: 120 Loss: 0.7157974243164062
# Epoch: 130 Loss: 0.6813316941261292
# Epoch: 140 Loss: 0.6499962210655212
# Epoch: 150 Loss: 0.6214578747749329
# Epoch: 160 Loss: 0.595411479473114
# Epoch: 170 Loss: 0.5715833306312561
# Epoch: 180 Loss: 0.5497309565544128
# Epoch: 190 Loss: 0.5296409130096436
# Epoch: 200 Loss: 0.5111258029937744
# Epoch: 210 Loss: 0.4940211772918701
# Epoch: 220 Loss: 0.478182852268219
# Epoch: 230 Loss: 0.46348387002944946
# Epoch: 240 Loss: 0.44981279969215393
# Epoch: 250 Loss: 0.43707114458084106
# Epoch: 260 Loss: 0.42517197132110596
# Epoch: 270 Loss: 0.4140382409095764
# Epoch: 280 Loss: 0.4036015570163727
# Epoch: 290 Loss: 0.3938010632991791
# Epoch: 300 Loss: 0.3845825791358948
# Epoch: 310 Loss: 0.37589752674102783
# Epoch: 320 Loss: 0.36770230531692505
# Epoch: 330 Loss: 0.35995784401893616
# Epoch: 340 Loss: 0.352629154920578
# Epoch: 350 Loss: 0.34568434953689575
# Epoch: 360 Loss: 0.3390948176383972
# Epoch: 370 Loss: 0.3328346014022827
# Epoch: 380 Loss: 0.3268800675868988
# Epoch: 390 Loss: 0.3212099075317383
# Epoch: 400 Loss: 0.31580454111099243
# Epoch: 410 Loss: 0.3106461763381958
# Epoch: 420 Loss: 0.3057185411453247
# Epoch: 430 Loss: 0.30100664496421814
# Epoch: 440 Loss: 0.2964968681335449
# Epoch: 450 Loss: 0.29217660427093506
# Epoch: 460 Loss: 0.2880343794822693
# Epoch: 470 Loss: 0.28405946493148804
# Epoch: 480 Loss: 0.28024202585220337
# Epoch: 490 Loss: 0.2765730917453766
# Epoch: 500 Loss: 0.2730441093444824
# Epoch: 510 Loss: 0.26964735984802246
# Epoch: 520 Loss: 0.2663756012916565
# Epoch: 530 Loss: 0.2632221281528473
# Epoch: 540 Loss: 0.2601807415485382
# Epoch: 550 Loss: 0.2572454512119293
# Epoch: 560 Loss: 0.2544109523296356
# Epoch: 570 Loss: 0.2516721189022064
# Epoch: 580 Loss: 0.24902424216270447
# Epoch: 590 Loss: 0.24646292626857758
# Epoch: 600 Loss: 0.2439839392900467
# Epoch: 610 Loss: 0.2415834367275238
# Epoch: 620 Loss: 0.2392577975988388
# Epoch: 630 Loss: 0.23700356483459473
# Epoch: 640 Loss: 0.2348175346851349
# Epoch: 650 Loss: 0.23269663751125336
# Epoch: 660 Loss: 0.2306380718946457
# Epoch: 670 Loss: 0.22863908112049103
# Epoch: 680 Loss: 0.2266971617937088
# Epoch: 690 Loss: 0.2248099148273468
# Epoch: 700 Loss: 0.22297507524490356
# Epoch: 710 Loss: 0.22119049727916718
# Epoch: 720 Loss: 0.2194541096687317
# Epoch: 730 Loss: 0.21776407957077026
# Epoch: 740 Loss: 0.21611851453781128
# Epoch: 750 Loss: 0.21451571583747864
# Epoch: 760 Loss: 0.21295402944087982
# Epoch: 770 Loss: 0.21143192052841187
# Epoch: 780 Loss: 0.20994789898395538
# Epoch: 790 Loss: 0.20850056409835815
# Epoch: 800 Loss: 0.20708858966827393
# Epoch: 810 Loss: 0.20571064949035645
# Epoch: 820 Loss: 0.2043655961751938
# Epoch: 830 Loss: 0.20305222272872925
# Epoch: 840 Loss: 0.20176948606967926
# Epoch: 850 Loss: 0.20051628351211548
# Epoch: 860 Loss: 0.19929161667823792
# Epoch: 870 Loss: 0.19809453189373016
# Epoch: 880 Loss: 0.196924090385437
# Epoch: 890 Loss: 0.1957794725894928
# Epoch: 900 Loss: 0.1946597695350647
# Epoch: 910 Loss: 0.19356422126293182
# Epoch: 920 Loss: 0.1924920380115509
# Epoch: 930 Loss: 0.19144250452518463
# Epoch: 940 Loss: 0.1904149055480957
# Epoch: 950 Loss: 0.1894085705280304
# Epoch: 960 Loss: 0.18842282891273499
# Epoch: 970 Loss: 0.18745705485343933
# Epoch: 980 Loss: 0.18651068210601807
# Epoch: 990 Loss: 0.18558311462402344
# Epoch: 1000 Loss: 0.18467381596565247

# %%
pred_train2 = sol2.call(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
pred_test2 = sol2(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
plt.scatter(X_train, pred_train2, c='r', label='Numerical - Training', marker='+', s=30)
plt.plot(X_test, pred_test2, c='g', label='Numerical - Test')
plt.plot(X_test, np.sin(np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
plt.legend()
plt.show()

# %% [markdown]
# ## Harmonic oscillator
#
# Now, let's try to reproduce the solutions for the harmonic oscillator
# $$-\frac{1}{2}\frac{d^2}{dx^2}\Psi(x)+\frac{1}{2}x^2\Psi(x)=E\Psi(x)$$
#  with the domain $x\in[-L,L]$.

# %%
X_train_ho = np.arange(-L, L, 0.04) + 1e-8
X_train_ho = X_train_ho.reshape(-1,1)

# %% [markdown]
# With boundary conditions $\Psi(-L)=0$ and $\Psi(L)=0$.

# %%
bcs3 = [{'variable':0, 'value':-L, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':lambda X: tf.constant(0., dtype='float64', shape=X.shape)}]

# %% [markdown]
# The term of the loss function representing the boundary conditions $\sum_k (\Psi(N(x_k))-C_k)^2$

# %%
def loss_harmonic(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  half = tf.constant(0.5, shape=(X.shape[0], 1), dtype='float64')
  eigen_value_tensor = tf.constant(eigen_value, shape=(X.shape[0], 1), dtype='float64')
  loss = tf.square(half*laplace + (eigen_value_tensor - half*response ** 2) * response)
  return loss

# %% [markdown]
# The analytic solution in terms of the Hermit polynomials.

# %%
def harmonic_analytic(X, n):
  # degree parameter of the polynomial
  c = np.zeros((n+1))
  c[n] = 1
  value = hermval(X, c)
  value *= np.power(np.pi, -0.25)
  value /= np.sqrt(2 ** n * factorial(n))
  value *= np.exp(-0.5*X**2)
  return value

# %% [markdown]
# The authors have found $n_h=40$ to be optimal size of the network for the problem.
#
# Let's check if such a solution finds the eigen function corresponidng to the first $5$ eigen_values calculated as $E(n)=n+0.5,\, n=0,1,2,3,\dots$ .

# %%
def eigen_value_harmonic(n):
  return n + 0.5

# %%
for n in range(0, 6):
  sol3 = Solution(n_i=1, n_h=40, n_o=2)
  sol3.train(X=X_train_ho, conditions=bcs3, eigen_value=eigen_value_harmonic(n), loss_function=loss_harmonic,
            loss_boundary=loss_boundary, epochs=1000, message_frequency=10, learning_rate=0.01,
            optimizer_name='Adam')
  pred_train3_ho = sol3.call(tf.convert_to_tensor(X_train_ho, dtype='float64')).numpy()
  plt.scatter(X_train_ho, pred_train3_ho, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_train_ho, harmonic_analytic(X_train_ho, n), c='b', label='Analytic')
  plt.legend()
  plt.show()
# Out:
# W0504 22:39:34.142550 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_23/dense_46/kernel:0', 'solution_23/dense_46/bias:0'] when minimizing the loss.
# W0504 22:39:35.504379 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_23/dense_46/kernel:0', 'solution_23/dense_46/bias:0'] when minimizing the loss.
# W0504 22:39:36.599923 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_23/dense_46/kernel:0', 'solution_23/dense_46/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 0.00012387055903673172
# Epoch: 20 Loss: 6.193546141730621e-05
# Epoch: 30 Loss: 0.0005693970597349107
# Epoch: 40 Loss: 0.005635058041661978
# Epoch: 50 Loss: 0.004508474841713905
# Epoch: 60 Loss: 0.0037570777349174023
# Epoch: 70 Loss: 0.0032203523442149162
# Epoch: 80 Loss: 0.00281780818477273
# Epoch: 90 Loss: 0.002504718489944935
# Epoch: 100 Loss: 0.002254246501252055
# W0504 22:39:54.999377 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_24/dense_48/kernel:0', 'solution_24/dense_48/bias:0'] when minimizing the loss.
# W0504 22:39:56.325783 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_24/dense_48/kernel:0', 'solution_24/dense_48/bias:0'] when minimizing the loss.
# W0504 22:39:57.306163 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_24/dense_48/kernel:0', 'solution_24/dense_48/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 0.00028486544033512473
# Epoch: 20 Loss: 0.00014243272016756237
# Epoch: 30 Loss: 0.0001542367390356958
# Epoch: 40 Loss: 0.00011567780165933073
# Epoch: 50 Loss: 9.25422427826561e-05
# Epoch: 60 Loss: 7.711853686487302e-05
# Epoch: 70 Loss: 6.61016019876115e-05
# Epoch: 80 Loss: 8.936078666010872e-05
# Epoch: 90 Loss: 7.943191303638741e-05
# Epoch: 100 Loss: 7.148872100515291e-05
# W0504 22:40:13.430786 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_25/dense_50/kernel:0', 'solution_25/dense_50/bias:0'] when minimizing the loss.
# W0504 22:40:14.659995 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_25/dense_50/kernel:0', 'solution_25/dense_50/bias:0'] when minimizing the loss.
# W0504 22:40:15.648096 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_25/dense_50/kernel:0', 'solution_25/dense_50/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 2722.95751953125
# Epoch: 20 Loss: 1409.3271484375
# Epoch: 30 Loss: 951.0498046875
# Epoch: 40 Loss: 718.5909423828125
# Epoch: 50 Loss: 578.1775512695312
# Epoch: 60 Loss: 484.2424621582031
# Epoch: 70 Loss: 417.0627746582031
# Epoch: 80 Loss: 366.67266845703125
# Epoch: 90 Loss: 327.2532958984375
# Epoch: 100 Loss: 294.5860900878906
# W0504 22:40:33.535563 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_26/dense_52/kernel:0', 'solution_26/dense_52/bias:0'] when minimizing the loss.
# W0504 22:40:34.751085 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_26/dense_52/kernel:0', 'solution_26/dense_52/bias:0'] when minimizing the loss.
# W0504 22:40:35.726350 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_26/dense_52/kernel:0', 'solution_26/dense_52/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 7.293665112229064e-05
# Epoch: 20 Loss: 3.646832556114532e-05
# Epoch: 30 Loss: 2.4312215828103945e-05
# Epoch: 40 Loss: 0.00021400769765023142
# Epoch: 50 Loss: 0.0013362020254135132
# Epoch: 60 Loss: 0.001113502192310989
# Epoch: 70 Loss: 0.0009544304339215159
# Epoch: 80 Loss: 0.0008358365739695728
# Epoch: 90 Loss: 0.0007429717225022614
# Epoch: 100 Loss: 0.0006838100380264223
# W0504 22:40:52.056540 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_27/dense_54/kernel:0', 'solution_27/dense_54/bias:0'] when minimizing the loss.
# W0504 22:40:53.380878 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_27/dense_54/kernel:0', 'solution_27/dense_54/bias:0'] when minimizing the loss.
# W0504 22:40:54.348536 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_27/dense_54/kernel:0', 'solution_27/dense_54/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 21.37115478515625
# Epoch: 20 Loss: 10.691064834594727
# Epoch: 30 Loss: 7.127376556396484
# Epoch: 40 Loss: 5.345532417297363
# Epoch: 50 Loss: 4.276425838470459
# Epoch: 60 Loss: 3.563688278198242
# Epoch: 70 Loss: 3.0545899868011475
# Epoch: 80 Loss: 2.6727662086486816
# Epoch: 90 Loss: 2.377009391784668
# Epoch: 100 Loss: 2.139308452606201
# W0504 22:41:10.582963 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_28/dense_56/kernel:0', 'solution_28/dense_56/bias:0'] when minimizing the loss.
# W0504 22:41:11.841000 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_28/dense_56/kernel:0', 'solution_28/dense_56/bias:0'] when minimizing the loss.
# W0504 22:41:12.925847 139828460254976 optimizer_v2.py:928] Gradients does not exist for variables ['solution_28/dense_56/kernel:0', 'solution_28/dense_56/bias:0'] when minimizing the loss.
# Epoch: 10 Loss: 86.37461853027344
# Epoch: 20 Loss: 66.15267944335938
# Epoch: 30 Loss: 59.36839294433594
# Epoch: 40 Loss: 55.954864501953125
# Epoch: 50 Loss: 47.84185028076172
# Epoch: 60 Loss: 39.86820983886719
# Epoch: 70 Loss: 34.172752380371094
# Epoch: 80 Loss: 29.90115737915039
# Epoch: 90 Loss: 26.578805923461914
# Epoch: 100 Loss: 23.92092514038086

# %% [markdown]
# What is interesting is that it is not even matter of normalization what could be a case, but the solution simply vanishes.
