# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.hermite import hermval
from scipy.misc import factorial
import naive_nde as nnde
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Reproduction: Shirvany, et. al., "Numerical solution of the nonlinear Schrodinger equation by feedforward neural networks."

# %% [markdown]
# The authors propose the solution of a form of a almost-shallow network where we have a single hidden layer with $n_h$ units with sigmoid activation function. Output of the hidden layer is passed to an output layer with $n_o=2$ linear units which in the end are reduced by multipication.

# %% [markdown]
# Accroding to the paper:
#
# >The ANN is trained via the gradient-descent back-propagation method with momentum
# term for minimizing the non-negative energy function that is formulated from Schrodinger equation Eq. (6)
# and the available boundary conditions.
#
# and
#
# >In the train
# state of the network the adjustable parameters of the networks (weights and biases) are tuned by a proper
# learning algorithm to minimize the energy function of the network. We train the network via the fast converge
# gradient-descend back-propagation method with momentum term [7,23,24] for the non-negative energy func-
# tion.
#
# We concluded that it can realised by using the Adam optimizer with online learning.

# %% [markdown]
# The loss is defined by sum of unsupervised minimalization of the equation and by supervised optimization for MSE for the boundary conditions:
# $$Loss(N)=\sum_i \left(\Delta\Psi(N(x_i))+E\Psi(N(x_i))\right)^2 + \sum_k (\Psi(N(x_k))-C_k)^2$$

# %% [markdown]
# ## Potential Well

# %% [markdown]
# We consider the Shroedinger equation in one dimension:
# $$-\frac{d^2}{dx^2}\Psi(x)+V(x)\Psi(x)=E\Psi(x)$$
# For the Potential Well problem with
# $$V(x)=\begin{cases}
#       0, & x\in[0,L] \\
#       \infty, & x\notin(0,L)
#    \end{cases}$$
# The equivalent formulation is $V(x)=0$ on the whole domain with the boundary conditions $\Psi(0)=0$ and $\Psi(L)=0$ with the domain of the equation $x\in[0,L]$.
#
#
# Where we set $\frac{\hbar^2}{2m}=1$.

# %% [markdown]
# We set the lenght of the well equal to $4$.

# %%
L = 4.

# %% [markdown]
# We take 200 equidistant points from the interval $[0, L]$ for the training set and more for the test set.

# %%
X_train = np.arange(0, L, L/200) + 1e-8
X_train = X_train.reshape(-1,1)
X_test = np.arange(0, L, 0.001) + 1e-8
X_test = X_test.reshape(-1,1)

# %%
# Defining the boundary conditions
def constant(c):
  def func(X):
    return tf.constant(c, dtype='float64', shape=X.shape)
  return func
bcs = [{'variable':0, 'value':0, 'type':'dirichlet',
        'function':constant(0.)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':constant(0.)}]

# %% [markdown]
# The term of the loss function representing the equation satisfaction $\sum_i \left(\Delta\Psi(N(x_i))+E\Psi(N(x_i))\right)^2$

# %%
def loss_well(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  # Taking the frist (grads) and the second (laplace) derivatives w. r. t. inputs
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  
  psi = tf.reshape(response, shape=(-1,))  
  nabla = tf.reshape(laplace, shape=(-1,))
  loss = (nabla + eigen_value * psi) ** 2
  
  return tf.math.reduce_mean(loss)

# %% [markdown]
# The authors have found $n_h=105$ to be optimal size of the network.
#
# Let's check if such a solution finds the eigen function corresponidng to the first $5$ eigen_values calculated as $E(n)=\left(\frac{n\pi}{L} \right)^2,\, n=1,2,3,\dots$ .

# %%
def eigen_value_well(n):
  return (n * np.pi / L)**2

# %% [markdown]
# Defining the function finding the solution and plotting.

# %%
def potential_well_solve_plot(n, normalize=False):
  sol = nnde.Solution(n_i=1, n_h=40, n_o=2)
  sol.train(X=X_train, conditions=bcs, eigen_value=eigen_value_well(n), loss_function=loss_well,
            epochs=10000, verbose=False, message_frequency=100, boundary_multiplier=0.1,
            learning_rate=0.01, optimizer_name='Adam')
  
  pred_train = sol(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
  train_normalization = (pred_train**2).sum()*L/pred_train.shape[0]
  print(train_normalization)
  if normalize:
    pred_train /= train_normalization
  pred_test = sol(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
  test_normalization = (pred_test**2).sum()*L/pred_test.shape[0]
  print(test_normalization)
  if normalize:
    pred_test /= test_normalization
  plt.scatter(X_train, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_test, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_test, np.sin(n*np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
  return sol

# %% [markdown]
# For $n=1$.

# %%
pw_n1 = potential_well_solve_plot(1)
# Out:
# 5.869761483972316e-15
# 5.909583201037096e-15

# %% [markdown]
# For $n=2$.

# %%
pw_n2 = potential_well_solve_plot(2)
# Out:
# 2.029771735538661e-10
# 2.0297680067588035e-10

# %% [markdown]
# For $n=3$.

# %%
pw_n3 = potential_well_solve_plot(3)
# Out:
# 2.8812626301100686e-06
# 2.8860209111835365e-06

# %% [markdown]
# For $n=4$.

# %%
pw_n4 = potential_well_solve_plot(4)
# Out:
# 1.2365507775967522e-11
# 1.2449843055003205e-11

# %% [markdown]
# For $n=5$.

# %%
pw_n5 = potential_well_solve_plot(5)
# Out:
# 3.7237564699062564e-13
# 3.7471316476027404e-13

# %% [markdown]
# For $n=6$.

# %%
pw_n6 = potential_well_solve_plot(6)
# Out:
# 8.915882966613691e-12
# 8.929295732668606e-12

# %% [markdown]
# ### Normalization
#
# The network converges to an almost trivial vanishing solution of the equation, so we try to normalize the solution to see whether it is only a problem of the scale or is it total failure in solving the equation.

# %% [markdown]
# For $n=1$.

# %%
pw_n1 = potential_well_solve_plot(1, normalize=True)
# Out:
# 5.379885117708205e-09
# 5.379885232671949e-09

# %% [markdown]
# For $n=2$.

# %%
pw_n2 = potential_well_solve_plot(2, normalize=True)
# Out:
# 4.362795354098785e-12
# 4.363074763535658e-12

# %% [markdown]
# For $n=3$.

# %%
pw_n3 = potential_well_solve_plot(3, normalize=True)
# Out:
# 1.149016526094187e-08
# 1.1487414756874832e-08

# %% [markdown]
# For $n=4$.

# %%
pw_n4 = potential_well_solve_plot(4, normalize=True)
# Out:
# 1.1335736991014639e-13
# 1.117476023598794e-13

# %% [markdown]
# For $n=5$.

# %%
pw_n5 = potential_well_solve_plot(5, normalize=True)
# Out:
# 3.6350310598435316e-12
# 3.642588022202899e-12

# %% [markdown]
# For $n=6$.

# %%
pw_n6 = potential_well_solve_plot(6, normalize=True)
# Out:
# 3.2626878543367356e-14
# 3.2640180357856917e-14

# %% [markdown]
# ### Let's try to fix it by adding an additional point
#
# By analytic considerations, we know that for $n=1$ the maximum of the eigenfunction is for $x=L/2$ and is equal to $\Psi(L/2)=2^{-0.5}$, so let's add it as an additional initial condition.

# %%
bcs2 = [{'variable':0, 'value':0, 'type':'dirichlet',
        'function':constant(0.)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':constant(0.)},
      {'variable':0, 'value':L*0.5, 'type':'dirichlet',
        'function':constant(np.power(2,-0.5))}]

# %%
sol2 = nnde.Solution(n_i=1, n_h=105, n_o=2)

# %% [markdown]
# For $n=1$.

# %%
sol2.train(X=X_train, conditions=bcs2, eigen_value=eigen_value_well(1), loss_function=loss_well,
           epochs=10000, message_frequency=1000,learning_rate=0.01, optimizer_name='Adam', verbose=True)
# Out:
# Epoch: 1000 Loss equation:                     0.01615221439605413                     Loss boundary: 0.0021490839837319028
# Epoch: 2000 Loss equation:                     0.0015337121940500536                     Loss boundary: 0.00034367069063098623
# Epoch: 3000 Loss equation:                     0.001624292846585966                     Loss boundary: 9.523420805033065e-06
# Epoch: 4000 Loss equation:                     0.0013154599970527237                     Loss boundary: 4.927220664030208e-05
# Epoch: 5000 Loss equation:                     0.0007148742157333482                     Loss boundary: 0.00014386540880474008
# Epoch: 6000 Loss equation:                     0.000571735524892894                     Loss boundary: 0.00017589480015714395
# Epoch: 7000 Loss equation:                     0.0005482667633073281                     Loss boundary: 0.0004022093652894679
# Epoch: 8000 Loss equation:                     0.0003540392144718136                     Loss boundary: 0.0001232013184703548
# Epoch: 9000 Loss equation:                     0.0009084363370632373                     Loss boundary: 0.00032572635128355165
# Epoch: 10000 Loss equation:                     0.0008010635416877468                     Loss boundary: 0.0001919210163455731
# <tf.Tensor: id=4122958, shape=(), dtype=float64, numpy=0.00099298455803332>

# %%
pred_train2 = sol2(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
# pred_train2 /= pred_train2.max()
pred_test2 = sol2(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
# pred_test2 /= pred_test2.max()
plt.scatter(X_train, pred_train2, c='r', label='Numerical - Training', marker='+', s=30)
plt.plot(X_test, pred_test2, c='g', label='Numerical - Test')
plt.plot(X_test, np.sin(np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
plt.legend()
plt.show()

# %% [markdown]
# This is a convincing sanity check that the network works, but requires additional condition, so the solution does not vanish.

# %% [markdown]
# ## Forcing summation to **1** - probabilistic interpretation

# %%
def loss_well_unity(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  # Taking the frist (grads) and the second (laplace) derivatives w. r. t. inputs
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  
  psi = tf.reshape(response, shape=(-1,))  
  nabla = tf.reshape(laplace, shape=(-1,))
  loss = (nabla + eigen_value * psi) ** 2
  
  interval = X[1]
  probability_unity = tf.math.reduce_sum(response**2) * interval 
  probability_unity = (probability_unity - 1) **2
  loss = tf.math.reduce_mean(loss) + probability_unity
  return loss

# %%
def potential_well_unity_solve_plot_arbitrary_eig(eig, n):
  sol = nnde.Solution(n_i=1, n_h=40, n_o=2)
  sol.train(X=X_train, conditions=bcs, eigen_value=eig, loss_function=loss_well_unity,
            epochs=50000, verbose=True, message_frequency=1000, boundary_multiplier=0.1,
            learning_rate=0.01, optimizer_name='Adam')
  
  pred_train = sol(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
  train_normalization = (pred_train**2).sum()*L/pred_train.shape[0]
  print(train_normalization)
  pred_train /= np.sign(pred_train.sum())
  pred_test = sol(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
  test_normalization = (pred_test**2).sum()*L/pred_test.shape[0]
  print(test_normalization)
  pred_test /= np.sign(pred_test.sum())
  plt.scatter(X_train, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_test, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_test, np.sin(n*np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
  return sol

# %%
potentia

# %%
def potential_well_unity_solve_plot(n):
  sol = nnde.Solution(n_i=1, n_h=40, n_o=2)
  sol.train(X=X_train, conditions=bcs, eigen_value=eigen_value_well(n), loss_function=loss_well_unity,
            epochs=50000, verbose=True, message_frequency=1000, boundary_multiplier=0.1,
            learning_rate=0.01, optimizer_name='Adam')
  
  pred_train = sol(tf.convert_to_tensor(X_train, dtype='float64')).numpy()
  train_normalization = (pred_train**2).sum()*L/pred_train.shape[0]
  print(train_normalization)
  pred_train /= np.sign(pred_train.sum())
  pred_test = sol(tf.convert_to_tensor(X_test, dtype='float64')).numpy()
  test_normalization = (pred_test**2).sum()*L/pred_test.shape[0]
  print(test_normalization)
  pred_test /= np.sign(pred_test.sum())
  plt.scatter(X_train, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_test, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_test, np.sin(n*np.pi/L*X_test)/np.sqrt(2), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
  return sol

# %% [markdown]
# For $n=1$.

# %%
pwu_n1 = potential_well_unity_solve_plot(1)
# Out:
# Epoch: 1000 Loss equation:               [0.08812004]               Loss boundary: 0.04518767252580658
# Epoch: 2000 Loss equation:               [0.02366389]               Loss boundary: 0.009778892984182663
# Epoch: 3000 Loss equation:               [0.00145162]               Loss boundary: 7.706002061711736e-05
# Epoch: 4000 Loss equation:               [0.00213842]               Loss boundary: 9.79709996725995e-05
# Epoch: 5000 Loss equation:               [0.00180632]               Loss boundary: 5.795446499240551e-06
# Epoch: 6000 Loss equation:               [0.00409011]               Loss boundary: 7.000631743304859e-05
# Epoch: 7000 Loss equation:               [0.00353182]               Loss boundary: 5.060201515756346e-05
# Epoch: 8000 Loss equation:               [0.00306026]               Loss boundary: 4.250287154571039e-05
# Epoch: 43000 Loss equation:               [3.54734099e-06]               Loss boundary: 6.752522710339075e-10
# Epoch: 44000 Loss equation:               [2.07638653e-05]               Loss boundary: 3.5462659917780426e-08
# Epoch: 45000 Loss equation:               [3.74663206e-05]               Loss boundary: 5.79407158517325e-07
# Epoch: 46000 Loss equation:               [3.18685491e-06]               Loss boundary: 4.254726664197057e-10
# Epoch: 47000 Loss equation:               [2.88628047e-05]               Loss boundary: 6.119093768338459e-08
# Epoch: 48000 Loss equation:               [2.9670712e-06]               Loss boundary: 5.4333693322967656e-11
# Epoch: 49000 Loss equation:               [9.95038652e-05]               Loss boundary: 5.78085764816857e-08
# Epoch: 50000 Loss equation:               [1.95598071e-05]               Loss boundary: 3.249195835922517e-08
# 1.0002375157150456
# 1.0002374921145625

# %% [markdown]
# For $n=2$.

# %%
pwu_n2 = potential_well_unity_solve_plot(2)
# Out:
# Epoch: 1000 Loss equation:               [0.26581461]               Loss boundary: 0.06342747849420796
# Epoch: 2000 Loss equation:               [0.04072203]               Loss boundary: 0.07497513521699709
# Epoch: 3000 Loss equation:               [0.31482491]               Loss boundary: 0.036200644760906335
# Epoch: 4000 Loss equation:               [0.06998845]               Loss boundary: 0.04106381976657352
# Epoch: 5000 Loss equation:               [0.01276038]               Loss boundary: 0.0022352551559234124
# Epoch: 6000 Loss equation:               [0.00471952]               Loss boundary: 0.00036971533811895965
# Epoch: 7000 Loss equation:               [0.0045465]               Loss boundary: 0.00032644168993274756
# Epoch: 8000 Loss equation:               [0.00473385]               Loss boundary: 0.0020989217299912733
# Epoch: 9000 Loss equation:               [0.0018007]               Loss boundary: 0.00024454675222030227
# Epoch: 10000 Loss equation:               [0.00132754]               Loss boundary: 8.944488575424186e-05
# Epoch: 11000 Loss equation:               [0.00115331]               Loss boundary: 5.3469431250703204e-05
# Epoch: 12000 Loss equation:               [0.00097623]               Loss boundary: 3.3425943996559774e-05
# Epoch: 13000 Loss equation:               [0.00050733]               Loss boundary: 1.29098236024212e-05
# Epoch: 14000 Loss equation:               [0.00370214]               Loss boundary: 7.132935922577526e-05
# Epoch: 15000 Loss equation:               [0.00029582]               Loss boundary: 4.927458932506888e-06
# Epoch: 16000 Loss equation:               [0.00080113]               Loss boundary: 2.3592710155381136e-05
# Epoch: 17000 Loss equation:               [0.00118529]               Loss boundary: 2.606709071420484e-05
# Epoch: 18000 Loss equation:               [0.00109923]               Loss boundary: 2.2915070743375537e-05
# Epoch: 19000 Loss equation:               [0.00012951]               Loss boundary: 3.6357854907986823e-06
# Epoch: 20000 Loss equation:               [0.00120542]               Loss boundary: 4.656026104877427e-05
# Epoch: 21000 Loss equation:               [0.00152845]               Loss boundary: 4.921942871065411e-05
# Epoch: 22000 Loss equation:               [6.15118614e-05]               Loss boundary: 2.720008984419506e-07
# Epoch: 23000 Loss equation:               [0.00053343]               Loss boundary: 1.0942800797168764e-05
# Epoch: 24000 Loss equation:               [6.57446767e-05]               Loss boundary: 5.289010909479333e-07
# Epoch: 49000 Loss equation:               [1.]               Loss boundary: 1.6205363402927251e-16
# Epoch: 50000 Loss equation:               [1.00000021]               Loss boundary: 1.9593103156425753e-10
# 2.1740584632833247e-09
# 2.185802736362341e-09

# %% [markdown]
# ## Harmonic oscillator
#
# Now, let's try to reproduce the solutions for the harmonic oscillator
# $$-\frac{1}{2}\frac{d^2}{dx^2}\Psi(x)+\frac{1}{2}x^2\Psi(x)=E\Psi(x)$$
#  with the domain $x\in[-L,L]$.

# %%
X_train_ho = np.arange(-L, L, 2*L/200) + 1e-8
X_train_ho = X_train_ho.reshape(-1,1)

# %% [markdown]
# With boundary conditions $\Psi(-L)=0$ and $\Psi(L)=0$.

# %%
bcs3 = [{'variable':0, 'value':-L, 'type':'dirichlet',
        'function':constant(0.)},
      {'variable':0, 'value':L, 'type':'dirichlet',
        'function':constant(0.)}]

# %% [markdown]
# The term of the loss function representing the boundary conditions $\sum_k (\Psi(N(x_k))-C_k)^2$

# %%
def loss_harmonic(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  
  nabla = tf.reshape(laplace, shape=(-1,))
  psi = tf.reshape(response, shape=(-1,))
  x = tf.reshape(X, shape=(-1,))
  
  eigen_value_tensor = tf.constant(eigen_value, shape=(X.shape[0], ), dtype='float64')
  
  loss = tf.square(0.5*nabla + (eigen_value_tensor - 0.5*x** 2) * psi)
  
  return tf.math.reduce_mean(loss)

# %% [markdown]
# The analytic solution in terms of the Hermit polynomials.

# %%
def harmonic_analytic(X, n):
  # degree parameter of the polynomial
  c = np.zeros((n+1))
  c[n] = 1
  value = hermval(X, c)
  value *= np.power(np.pi, -0.25)
  value /= np.sqrt(2 ** n * factorial(n))
  value *= np.exp(-0.5*X**2)
  return value

# %% [markdown]
# The authors have found $n_h=40$ to be optimal size of the network for the problem.
#
# Let's check if such a solution finds the eigen function corresponidng to the first $5$ eigen_values calculated as $E(n)=n+0.5,\, n=0,1,2,3,\dots$ .

# %%
def eigen_value_harmonic(n):
  return n + 0.5

# %%
def harmonic_solve_plot(n, normalization=False):
  sol = Solution(n_i=1, n_h=40, n_o=2)
  sol.train(X=X_train_ho, conditions=bcs3, eigen_value=eigen_value_well(n), loss_function=loss_harmonic,
            epochs=10000, verbose=True, message_frequency=1000, boundary_multiplier=0.1,
            learning_rate=0.1, optimizer_name='Adam')
  
  pred_train = sol(tf.convert_to_tensor(X_train_ho, dtype='float64')).numpy()
  train_normalization = (pred_train**2).sum()*L/pred_train.shape[0]
  print(train_normalization)
  if normalization:
    pred_train /= np.sign(pred_train.sum())
  pred_test = sol(tf.convert_to_tensor(X_train_ho, dtype='float64')).numpy()
  test_normalization = (pred_test**2).sum()*L/pred_test.shape[0]
  print(test_normalization)
  if normalization:
    pred_test /= np.sign(pred_test.sum())
  plt.scatter(X_train_ho, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_train_ho, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_train_ho, harmonic_analytic(X_train_ho, n), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
  return sol

# %% [markdown]
# For $n=0$.

# %%
ho_n0 = harmonic_solve_plot(0)
# Out:
# Epoch: 1000 Loss equation:               1.8352332656849016e-06               Loss boundary: 8.124888954953781e-08
# Epoch: 2000 Loss equation:               4.773577272861491e-07               Loss boundary: 2.4519866613144665e-08
# Epoch: 3000 Loss equation:               2.8041813376313324e-07               Loss boundary: 1.0882650363554182e-08
# Epoch: 4000 Loss equation:               2.2056503912219326e-07               Loss boundary: 8.177171343831329e-09
# Epoch: 5000 Loss equation:               1.2614549621501266e-07               Loss boundary: 5.012990091528294e-09
# Epoch: 6000 Loss equation:               1.7839373320439216e-08               Loss boundary: 5.792189565731516e-10
# Epoch: 7000 Loss equation:               1.7312912660657179e-09               Loss boundary: 2.7959951231342843e-11
# Epoch: 8000 Loss equation:               9.088248105003107e-10               Loss boundary: 5.9233910630289405e-12
# Epoch: 9000 Loss equation:               0.015161993672304041               Loss boundary: 0.00046242221638297077
# Epoch: 10000 Loss equation:               0.0006514794164682847               Loss boundary: 4.001923395539531e-05
# 5.5758217772119006e-05
# 5.5758217772119006e-05

# %% [markdown]
# For $n=1$.

# %%
ho_n1 = harmonic_solve_plot(1)
# Out:
# Epoch: 1000 Loss equation:               1.1025448567824265e-06               Loss boundary: 8.643851076293146e-08
# Epoch: 2000 Loss equation:               4.975907738115143e-07               Loss boundary: 7.615764007487324e-08
# Epoch: 3000 Loss equation:               1.9884483112272105e-07               Loss boundary: 1.595408716949756e-08
# Epoch: 4000 Loss equation:               0.0002591670714085666               Loss boundary: 5.612617582635546e-06
# Epoch: 5000 Loss equation:               1.2185383101563745e-08               Loss boundary: 1.398368698804383e-09
# Epoch: 6000 Loss equation:               4.654769332941152e-09               Loss boundary: 2.9618628955325766e-12
# Epoch: 7000 Loss equation:               2.534075279795312e-09               Loss boundary: 3.7595826535817316e-12
# Epoch: 8000 Loss equation:               1.1879153319518804e-09               Loss boundary: 5.897842490575818e-12
# Epoch: 9000 Loss equation:               5.713317194324537e-10               Loss boundary: 6.8073294087998276e-12
# Epoch: 10000 Loss equation:               2.1299346350843796e-10               Loss boundary: 1.305793840064041e-12
# 1.9215371012281047e-08
# 1.9215371012281047e-08

# %% [markdown]
# For $n=2$.

# %%
ho_n2 = harmonic_solve_plot(2)
# Out:
# Epoch: 1000 Loss equation:               2.2165674802304623e-06               Loss boundary: 3.1453307185640994e-07
# Epoch: 2000 Loss equation:               3.3962344250131096e-07               Loss boundary: 6.191773451724547e-08
# Epoch: 3000 Loss equation:               1.7886186382253541e-07               Loss boundary: 4.1560978456336145e-08
# Epoch: 4000 Loss equation:               7.91108385905785e-08               Loss boundary: 2.2534862687964238e-08
# Epoch: 5000 Loss equation:               1.2427466459372878e-08               Loss boundary: 4.886617694016892e-09
# Epoch: 6000 Loss equation:               6.766431570465515e-09               Loss boundary: 2.6194102901594585e-09
# Epoch: 7000 Loss equation:               1.559172343951651e-09               Loss boundary: 1.1795707173517762e-10
# Epoch: 8000 Loss equation:               7.706437491866499e-10               Loss boundary: 1.4436035727630097e-10
# Epoch: 9000 Loss equation:               1.445930360613018e-10               Loss boundary: 5.622893472051581e-11
# Epoch: 10000 Loss equation:               1.1033092395237184e-10               Loss boundary: 3.938878575018392e-11
# 5.517702205806785e-10
# 5.517702205806785e-10

# %% [markdown]
# For $n=3$.

# %%
ho_n3 = harmonic_solve_plot(3)
# Out:
# Epoch: 1000 Loss equation:               2.4667568907733664e-06               Loss boundary: 1.2419739326629896e-06
# Epoch: 2000 Loss equation:               1.2225437094169078e-07               Loss boundary: 4.428278008313554e-08
# Epoch: 3000 Loss equation:               1.068653528094498e-06               Loss boundary: 3.3284129178458897e-07
# Epoch: 4000 Loss equation:               5.427095321303324e-08               Loss boundary: 1.3149388059327333e-08
# Epoch: 5000 Loss equation:               1.4623034010562531e-08               Loss boundary: 4.32148948138854e-09
# Epoch: 6000 Loss equation:               6.3492373791137705e-09               Loss boundary: 1.6966921212972915e-09
# Epoch: 7000 Loss equation:               2.837382988707382e-09               Loss boundary: 6.965897015726182e-10
# Epoch: 8000 Loss equation:               4.4880835816050977e-10               Loss boundary: 1.7575740385401693e-11
# Epoch: 9000 Loss equation:               3.501304571607034e-10               Loss boundary: 1.5483644960539603e-11
# Epoch: 10000 Loss equation:               1.8924352780067148e-10               Loss boundary: 3.5105173009297104e-11
# 9.878467363738201e-11
# 9.878467363738201e-11

# %% [markdown]
# For $n=4$.

# %%
ho_n4 = harmonic_solve_plot(4)
# Out:
# Epoch: 1000 Loss equation:               0.0005244314286909815               Loss boundary: 3.003116083911226e-05
# Epoch: 2000 Loss equation:               0.0001389694549402037               Loss boundary: 7.999506638229905e-06
# Epoch: 3000 Loss equation:               1.8255235515645137e-05               Loss boundary: 9.911975900007798e-07
# Epoch: 4000 Loss equation:               9.026774028451197e-08               Loss boundary: 4.600033976048737e-09
# Epoch: 5000 Loss equation:               1.9130628744844462e-08               Loss boundary: 2.489992014770427e-10
# Epoch: 6000 Loss equation:               1.1039089934378717e-08               Loss boundary: 3.8155718942805855e-10
# Epoch: 7000 Loss equation:               9.737154225196531e-09               Loss boundary: 3.18888995576701e-10
# Epoch: 8000 Loss equation:               8.331434586511538e-09               Loss boundary: 2.2729813032485458e-10
# Epoch: 9000 Loss equation:               6.042167164021596e-09               Loss boundary: 1.6280985076584957e-10
# Epoch: 10000 Loss equation:               4.0204154652768735e-09               Loss boundary: 1.7853978168698108e-10
# 6.598956396775748e-10
# 6.598956396775748e-10

# %% [markdown]
# For $n=5$.

# %%
ho_n5 = harmonic_solve_plot(5)
# Out:
# Epoch: 1000 Loss equation:               0.0006577547999988123               Loss boundary: 7.714509303425496e-06
# Epoch: 2000 Loss equation:               6.35988301220694e-05               Loss boundary: 8.259802529388963e-07
# Epoch: 3000 Loss equation:               1.0327767523019578e-05               Loss boundary: 1.1814496405838028e-07
# Epoch: 4000 Loss equation:               2.3377718882153073e-06               Loss boundary: 2.006053882128747e-08
# Epoch: 5000 Loss equation:               5.140907770055079e-07               Loss boundary: 1.5184397704361277e-09
# Epoch: 6000 Loss equation:               1.2711901006901063e-07               Loss boundary: 2.468580896735497e-10
# Epoch: 7000 Loss equation:               6.41610139626716e-08               Loss boundary: 5.670920423020237e-10
# Epoch: 8000 Loss equation:               1.3078718065485785e-08               Loss boundary: 9.648040074120338e-12
# Epoch: 9000 Loss equation:               0.7089351478903003               Loss boundary: 0.016575602123143452
# Epoch: 10000 Loss equation:               0.11054112155997736               Loss boundary: 0.004921475586746611
# 0.03210731282068742
# 0.03210731282068742

# %% [markdown]
# Let's try to normalize it and see what does the solution look like.

# %% [markdown]
# For $n=0$.

# %%
ho_n0 = harmonic_solve_plot(0, normalization=True)
# Out:
# Epoch: 1000 Loss equation:
# 0.0029719946896066916
# 0.0029719946896066916

# %% [markdown]
# What is interesting is that it is not even matter of normalization what could be a case, but the solution simply vanishes.

# %% [markdown]
# ## Forcing summation to **1** - probabilistic interpretation

# %%
def loss_harmonic_unity(network, X, eigen_value):
  X = tf.convert_to_tensor(X)
  
  with tf.GradientTape() as tape1:
    with tf.GradientTape() as tape2:
      tape1.watch(X)
      tape2.watch(X)
      response = network(X)
    grads = tape2.gradient(response, X)
  laplace = tape1.gradient(grads, X)
  
  nabla = tf.reshape(laplace, shape=(-1,))
  psi = tf.reshape(response, shape=(-1,))
  x = tf.reshape(X, shape=(-1,))
  
  eigen_value_tensor = tf.constant(eigen_value, shape=(X.shape[0], ), dtype='float64')
  
  loss = tf.square(0.5*nabla + (eigen_value_tensor - 0.5*x** 2) * psi)
  
  interval = X[1]-X[0]
  probability_unity = tf.math.reduce_sum(response**2) * interval 
  probability_unity = (probability_unity - 1) **2
  loss = tf.math.reduce_mean(loss) + probability_unity
  return loss

# %%
def harmonic_solve_plot_unity(n):
  sol = Solution(n_i=1, n_h=105, n_o=2)
  sol.train(X=X_train_ho, conditions=bcs3, eigen_value=eigen_value_well(n), loss_function=loss_harmonic_unity,
            epochs=50000, verbose=True, message_frequency=1000, boundary_multiplier=0.1,
            learning_rate=0.01, optimizer_name='Adam')
  
  pred_train = sol(tf.convert_to_tensor(X_train_ho, dtype='float64')).numpy()
  train_normalization = (pred_train**2).sum()*2*L/pred_train.shape[0]
  print(train_normalization)
  pred_train /= np.sign(pred_train.sum())
  pred_test = sol(tf.convert_to_tensor(X_train_ho, dtype='float64')).numpy()
  test_normalization = (pred_test**2).sum()*2*L/pred_test.shape[0]
  print(test_normalization)
  pred_test /= np.sign(pred_test.sum())
  plt.scatter(X_train_ho, pred_train, c='r', label='Numerical - Training', marker='+', s=30)
  plt.plot(X_train_ho, pred_test, c='g', label='Numerical - Test')
  plt.plot(X_train_ho, harmonic_analytic(X_train_ho, n), c='b', label='Analytic')
  plt.legend()
  plt.title(f'Solution for n={n}')
  plt.show()
  return sol

# %% [markdown]
# For $n=0$.

# %%
hou_n0 = harmonic_solve_plot_unity(0)
# Out:
# Epoch: 1000 Loss equation:               [0.11575745]               Loss boundary: 0.0010730382984210367
# Epoch: 2000 Loss equation:               [0.09280144]               Loss boundary: 0.0008257171577082858
# Epoch: 3000 Loss equation:               [0.05242126]               Loss boundary: 0.00020444913604261898
# Epoch: 4000 Loss equation:               [0.03297653]               Loss boundary: 9.755644195650166e-06
# Epoch: 5000 Loss equation:               [0.05081]               Loss boundary: 2.8842042557848866e-05
# Epoch: 6000 Loss equation:               [0.05094398]               Loss boundary: 7.3219694099413245e-06
# Epoch: 7000 Loss equation:               [0.04800646]               Loss boundary: 7.912832829372827e-07
# Epoch: 8000 Loss equation:               [0.04488704]               Loss boundary: 9.450872499193738e-08
# Epoch: 9000 Loss equation:               [0.04223707]               Loss boundary: 6.936494515486479e-08
# Epoch: 10000 Loss equation:               [0.04012982]               Loss boundary: 8.586082365403725e-09
# Epoch: 11000 Loss equation:               [0.03844717]               Loss boundary: 1.1724471486748986e-09
# Epoch: 39000 Loss equation:               [1.004062]               Loss boundary: 5.331144907557836e-05
# Epoch: 40000 Loss equation:               [1.00133077]               Loss boundary: 2.220174927172265e-05
# Epoch: 41000 Loss equation:               [1.00049875]               Loss boundary: 9.140254828866356e-06
# Epoch: 42000 Loss equation:               [1.00006765]               Loss boundary: 1.4608696935039538e-06
# Epoch: 43000 Loss equation:               [1.00000328]               Loss boundary: 8.735565110324131e-08
# Epoch: 44000 Loss equation:               [1.00000079]               Loss boundary: 1.9356581440756805e-08
# Epoch: 45000 Loss equation:               [1.00000063]               Loss boundary: 9.73147685765599e-09
# Epoch: 46000 Loss equation:               [1.0000003]               Loss boundary: 5.787605704753416e-09
# Epoch: 47000 Loss equation:               [1.00000016]               Loss boundary: 3.580063382890308e-09
# Epoch: 48000 Loss equation:               [1.00000011]               Loss boundary: 2.5273296590982436e-09
# Epoch: 49000 Loss equation:               [1.]               Loss boundary: 1.1613084473804853e-10
# Epoch: 50000 Loss equation:               [1.]               Loss boundary: 2.6030444205856097e-11
# 1.1180326839945469e-10
# 1.1180326839945469e-10

# %% [markdown]
# ## Automatic eigenvalue search
#
# Now, we implement the automatic eigenvalue search proposed by the authors.

# %%
# %load_ext autoreload
# %autoreload 2
import naive_nde as nnde
import solver
X_train, X_test = nnde.train_test_domain_a_to_b(0, 4.)
solving_machine = solver.Solver(tolerance=1e-4, delta_E=1e-1, max_iter=10000, max_eigen_counter=10, n_h=100)
eigen_value, network = solving_machine.solve(X=X_train,
    conditions=nnde.zero_boundary_conditions(0, 4.), loss_function=nnde.loss_well_unity, learning_rate=0.001)
print(eigen_value)
# print(eigen_value, network.total_loss(X=nnde.train_test_domain_a_to_b(0, 4.),
#     conditions=nnde.zero_boundary_conditions(0, 4.), boundary_multiplier=1, eigen_value=eigen_value))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loss: [0.09703948] for n: 0
# Rising the eigen value number 1
# Loss: [0.06503566] for n: 0.1
# Rising the eigen value number 2
# Loss: [0.04252843] for n: 0.2
# Rising the eigen value number 3
# Loss: [0.02470419] for n: 0.30000000000000004
# Rising the eigen value number 4
# Loss: [0.01164104] for n: 0.4
# Rising the eigen value number 5
# Loss: [0.00339932] for n: 0.5
# Rising the eigen value number 6
# Loss: [7.5131727e-05] for n: 0.6
# break
# 6 tf.Tensor([7.5131727e-05], shape=(1,), dtype=float64)
# 0.6

# %%
import time
network.save_weights(f'./{time.time()}.h5')

# %%
network.compile(optimizer=tf.keras.optimizers.Adam)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0a7a89f00420> in <module>()
# ----> 1 network.compile(optimizer=tf.keras.optimizers.Adam)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     454     self._setattr_tracking = False  # pylint: disable=protected-access
#     455     try:
# --> 456       result = method(self, *args, **kwargs)
#     457     finally:
#     458       self._setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, distribute, **kwargs)
#     214
#     215     self._run_eagerly = run_eagerly
# --> 216     optimizer = optimizers.get(optimizer)
#     217
#     218     if distribute is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/optimizers.py in get(identifier)
#     853     return deserialize(config)
#     854   else:
# --> 855     raise ValueError('Could not interpret optimizer identifier:', identifier)
#
# ValueError: ('Could not interpret optimizer identifier:', <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>)
